# %% [markdown]
# <a href="https://colab.research.google.com/github/ranjitk11/myFirstProject/blob/main/car_price_prediction_with_machine_learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor

# %%
data = pd.read_csv('https://raw.githubusercontent.com/amankharwal/Website-data/master/CarPrice.csv')
data
# Out:
#      car_ID  symboling                   CarName fueltype aspiration  \
# 0         1          3        alfa-romero giulia      gas        std
# 1         2          3       alfa-romero stelvio      gas        std
# 2         3          1  alfa-romero Quadrifoglio      gas        std
# 3         4          2               audi 100 ls      gas        std
# 4         5          2                audi 100ls      gas        std
# ..      ...        ...                       ...      ...        ...
# 200     201         -1           volvo 145e (sw)      gas        std
# 201     202         -1               volvo 144ea      gas      turbo
# 202     203         -1               volvo 244dl      gas        std
# 203     204         -1                 volvo 246   diesel      turbo
# 204     205         -1               volvo 264gl      gas      turbo
#
#     doornumber      carbody drivewheel enginelocation  wheelbase  ...  \
# ...

# %%
plt.figure(figsize=(20,15))
sns.heatmap(data.corr(),annot=True)
plt.show()

# %%
df = data[["symboling", "wheelbase", "carlength", 
             "carwidth", "carheight", "curbweight", 
             "enginesize", "boreratio", "stroke", 
             "compressionratio", "horsepower", "peakrpm", 
             "citympg", "highwaympg", "price"]]
X = np.array(df['price'])
Y = np.array(df.drop(['price'],1))
XTrain,XTest,YTrain,YTest = train_test_split(Y,X,test_size=0.21)
# Out:
# <ipython-input-5-10ca8261124e>:7: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   Y = np.array(df.drop(['price'],1))

# %%
model = DecisionTreeRegressor()
model.fit(XTrain,YTrain)
# Out:
# DecisionTreeRegressor()

# %%
model.score(XTest,model.predict(XTest))
# Out:
# 1.0
